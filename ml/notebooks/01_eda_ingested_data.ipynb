# %% [markdown]
# # EDA: Foorilla ingested data
#
# Loads the latest dated CSV pull from `data/raw/foorilla/`.

# %%
import glob
import pandas as pd

# %%
# Pick up the most recent dated jobs CSV under data/raw/foorilla/
files = sorted(glob.glob("../data/raw/foorilla/jobs_*.csv"))
assert files, "No data found — run `python -m src.ingestion.fetch --endpoint jobs` or ask for the latest CSV."
latest = files[-1]
print(f"Loading: {latest}")

df = pd.read_csv(latest)
df.shape
# Out:
# Loading: ../data/raw/foorilla/jobs_2026-08-16.csv
# (326311, 28)

# %%
df.head()
# Out:
#         id                          company  company_id  company_is_agency  \
# 0  3453292                       正浩 EcoFlow       31967              False
# 1  3453293                               帆书       33804              False
# 2  3452632                    PMA Companies       37474              False
# 3  3452588  Central Business Solutions, Inc       24501               True
# 4  3452624  Central Business Solutions, Inc       24501               True
#
#                                                title  \
# 0                                            Ai算法工程师
# 1                                            Ai开发工程师
# 2                         Sr. Workforce Data Analyst
# 3  Title: Principal AI Engineer – Agentic AI | Co...
# 4  Principal Data Engineer (Python, AWS, Redshift...
#
#                        location  has_remote  work_mode  \
# 0                            深圳       False        NaN
# 1                            上海       False        NaN
# 2  Blue Bell, PA, United States       False        NaN
# 3        Irvine, CA; Irvine, CA       False        NaN
# 4                    Irvine, CA        True        NaN
#
#                    published expired  ... salary_min_usd  salary_max_usd  \
# 0  2026-08-15T18:02:21+00:00     NaN  ...        21360.0         35601.0
# 1  2026-08-15T17:30:53+00:00     NaN  ...        21360.0         35601.0
# 2  2026-08-15T16:25:33+00:00     NaN  ...        85000.0        115000.0
# 3  2026-08-15T15:54:04+00:00     NaN  ...       122600.0        168000.0
# 4  2026-08-15T15:54:03+00:00     NaN  ...       147000.0        170000.0
#
#   salary_min_eur  salary_max_eur  \
# 0        18466.0         30778.0
# 1        18466.0         30778.0
# 2        73484.0         99420.0
# 3       105991.0        145240.0
# 4       127085.0        146969.0
#
#                                               topics        topic_ids  \
# 0  Artificial Intelligence|Data, AI, and Machine ...           11|101
# 1  Artificial Intelligence|Data, AI, and Machine ...           11|101
# 2  Big Data|Data, AI, and Machine Learning|Data E...  12|101|9|100|85
# 3  Artificial Intelligence|Data, AI, and Machine ...        11|101|20
# 4  Big Data|Data, AI, and Machine Learning|Data E...         12|101|9
#
#                                                 tags        regions  \
# 0  AI|AI Engineer|Analyze multi source energy dat...   Asia/Pacific
# 1  Agent systems|AI|AI Engineer|Bachelor of Engin...   Asia/Pacific
# 2  Access Control|Analyst|Automate workforce repo...  North America
# 3  Agentic AI|Agent Orchestration|AI Engineer|AWS...  North America
# 4  Airflow|Amazon EMR|Amazon Redshift|Amazon Web ...  North America
#
#        countries                                          apply_url
# 0          China  https://ecoflow.jobs.feishu.cn/602892/position...
# 1          China  https://jobs.dushu365.com/index/position/76700...
# 2  United States  https://myjobs.adp.com/externalpmacompanies/cx...
# 3  United States  https://cbsinfosys.catsone.com/careers/4147/jo...
# 4  United States  https://cbsinfosys.catsone.com/careers/4147/jo...
#
# [5 rows x 28 columns]

# %%
df.isna().mean().sort_values(ascending=False)  # missingness by column, a natural first check
# Out:
# work_mode            0.829402
# salary_max           0.809249
# salary_min           0.793476
# salary_min_usd       0.084208
# salary_max_usd       0.084208
# salary_min_eur       0.077304
# salary_max_eur       0.077304
# salary_min_est       0.068790
# salary_max_est       0.068790
# salary_currency      0.068380
# expired              0.052174
# countries            0.023643
# regions              0.020045
# experience_level     0.001627
# experience_years     0.000288
# location             0.000061
# language             0.000021
# topic_ids            0.000000
# tags                 0.000000
# topics               0.000000
# id                   0.000000
# company              0.000000
# published            0.000000
# has_remote           0.000000
# title                0.000000
# company_is_agency    0.000000
# company_id           0.000000
# apply_url            0.000000
# dtype: float64
